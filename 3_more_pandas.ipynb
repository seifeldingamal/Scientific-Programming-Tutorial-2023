# %% [markdown]
# # Fundamentals of Scientific Programming: More Pandas

# %% [markdown]
# This tutorial is written by [Seifeldin Abouelella](https://github.com/seifeldingamal) for EE_2.06.

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# Load a dataset into a pandas DataFrame and clean the data by removing missing values, duplicates, and outliers.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data Source and documentation: [Here.](https://www.kaggle.com/datasets/adityakadiwal/water-potability)

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('./assets/water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
# Remove missing values
df.dropna(inplace=True)
df.reset_index(drop= True)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.417441     8.059332  356.886136
# 1      9.092223  181.101509  17978.986339     6.546600  310.135738
# 2      5.584087  188.313324  28748.687739     7.544869  326.678363
# 3     10.223862  248.071735  28749.716544     7.513408  393.663396
# 4      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 2006   8.989900  215.047358  15921.412018     6.297312  312.931022
# 2007   6.702547  207.321086  17246.920347     7.708117  304.510230
# 2008  11.491011   94.812545  37188.826022     9.263166  258.930600
# 2009   6.069616  186.659040  26138.780191     7.747547  345.700257
# 2010   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       363.266516       18.436524       100.341674   4.628771           0
# ...

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)
df.reset_index(drop= True)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.417441     8.059332  356.886136
# 1      9.092223  181.101509  17978.986339     6.546600  310.135738
# 2      5.584087  188.313324  28748.687739     7.544869  326.678363
# 3     10.223862  248.071735  28749.716544     7.513408  393.663396
# 4      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 2006   8.989900  215.047358  15921.412018     6.297312  312.931022
# 2007   6.702547  207.321086  17246.920347     7.708117  304.510230
# 2008  11.491011   94.812545  37188.826022     9.263166  258.930600
# 2009   6.069616  186.659040  26138.780191     7.747547  345.700257
# 2010   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       363.266516       18.436524       100.341674   4.628771           0
# ...

# %%
# Get Quantiles to identify outliers
Q1, Q3 = np.percentile(df['Solids'], q=[25, 75])
IQR = Q3 - Q1
Lower_Bound = Q1 - 1.5*IQR
Upper_Bound = Q3 + 1.5*IQR
print(f'Lower Bound = {Lower_Bound}' )
print(f'Upper Bound = {Upper_Bound}' )
# Out:
# Lower Bound = -1734.717124220855
# Upper Bound = 44532.969581398465

# %%
# Remove outliers
df[(df['Solids'] > Lower_Bound) & (df['Solids'] < Upper_Bound)]
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3265   8.197353  203.105091  27701.794055     6.472914  328.886838
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       363.266516       18.436524       100.341674   4.628771           0
# ...

# %% [markdown]
# ## 2. Data Manipulation

# %% [markdown]
# Use pandas to manipulate the data by filtering rows based on conditions, sorting the data, and grouping the data by categories.

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('./assets/pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Filter rows based on conditions
df[df['Name'] == 'Pikachu']
# Out:
#      #     Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 30  25  Pikachu  Electric    NaN    320  35      55       40       50
#
#     Sp. Def  Speed  Generation  Legendary
# 30       50     90           1      False

# %%
# Sort the data
df.sort_values('Name').head()
# Out:
#        #                     Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 510  460                Abomasnow    Grass    Ice    494  90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass    Ice    594  90     132      105
# 68    63                     Abra  Psychic    NaN    310  25      20       15
# 392  359                    Absol     Dark    NaN    465  65     130       60
# 393  359          AbsolMega Absol     Dark    NaN    565  65     150       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 68       105       55     90           1      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False

# %%
# Group the data by categories
df.groupby('Type 1').mean(numeric_only=True).head()
# Out:
#                    #       Total         HP      Attack    Defense    Sp. Atk  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014  70.724638  53.869565
# Dark      461.354839  445.741935  66.806452   88.387097  70.225806  74.645161
# Dragon    474.375000  550.531250  83.312500  112.125000  86.375000  96.843750
# Electric  363.500000  443.409091  59.795455   69.090909  66.295455  90.022727
# Fairy     449.529412  413.176471  74.117647   61.529412  65.705882  78.529412
#
#             Sp. Def      Speed  Generation  Legendary
# Type 1
# Bug       64.797101  61.681159    3.217391   0.000000
# Dark      69.516129  76.161290    4.032258   0.064516
# Dragon    88.843750  83.031250    3.875000   0.375000
# Electric  73.704545  84.500000    3.272727   0.090909
# Fairy     84.705882  48.588235    4.117647   0.058824

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
#  Use pandas and matplotlib to create visualizations of the data such as scatter plots, histograms, and box plots.

# %%
import matplotlib.pyplot as plt

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('./assets/water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
# Create a scatter plot
plt.scatter(df['Solids'], df['Organic_carbon'])
plt.xlabel('Solids')
plt.ylabel('Organic carbon')
plt.title('Scatter Plot')
plt.show()

# %%
# Create a histogram
plt.hist(df['Hardness'], bins=10)
plt.xlabel('Hardness')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
# Create a box plot
plt.boxplot(df['Chloramines'])
plt.xlabel('Chloramines')
plt.ylabel('Amount of Chloramines in ppm')
plt.title('Box Plot')
plt.show()

# %% [markdown]
# ## 4. Data Analysis

# %% [markdown]
# Use pandas to perform statistical analysis on the data such as calculating the mean, median, mode, standard deviation, and correlation.

# %%
# Calculate the mean
df['Sulfate'].mean()
# Out:
# 333.7757766108135

# %%
df.mean()
# Out:
# ph                     7.080795
# Hardness             196.369496
# Solids             22014.092526
# Chloramines            7.122277
# Sulfate              333.775777
# Conductivity         426.205111
# Organic_carbon        14.284970
# Trihalomethanes       66.396293
# Turbidity              3.966786
# Potability             0.390110
# dtype: float64

# %%
# Calculate the median
df['Sulfate'].median()
# Out:
# 333.073545745888

# %%
df.median()
# Out:
# ph                     7.036752
# Hardness             196.967627
# Solids             20927.833607
# Chloramines            7.130299
# Sulfate              333.073546
# Conductivity         421.884968
# Organic_carbon        14.218338
# Trihalomethanes       66.622485
# Turbidity              3.955028
# Potability             0.000000
# dtype: float64

# %%
# Calculate the standard deviation
df['Sulfate'].std()
# Out:
# 41.416840461672685

# %%
df.std()
# Out:
# ph                    1.594320
# Hardness             32.879761
# Solids             8768.570828
# Chloramines           1.583085
# Sulfate              41.416840
# Conductivity         80.824064
# Organic_carbon        3.308162
# Trihalomethanes      16.175008
# Turbidity             0.780382
# Potability            0.487849
# dtype: float64

# %%
# Calculate the correlation between two columns
df['Sulfate'].corr(df['Conductivity'])
# Out:
# -0.01612056448497827

# %%
df.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# ...
